# %% [markdown]
# # Mi primer codigo
# ##### para poder hacer ese titulo le puse un signo gato, mientras más signos gatos mas pequeña la letra y se pone shift+enter y aparece

# %%
print('Hola mundo')
# Out:
# Hola mundo

# %%
5+9
# Out:
# 14
